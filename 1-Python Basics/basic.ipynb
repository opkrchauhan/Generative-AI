# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are
#
# Semantics refers to the meaning or the interpretation of the symbols, characters and commands in a language. It is about what the code is supposed to so when it runs.

# %%
## Basic Syntax Rule in Python
## Case sensitivity --

name="Krish"
Name = "Nayak"

print(name)
print(Name)
# Out:
# Krish
# Nayak
